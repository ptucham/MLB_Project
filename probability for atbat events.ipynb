# %% [markdown]
# pybaseball github with install instructions: https://github.com/jldbc/pybaseball <br>
# Documentation for pybaseball library: https://github.com/jldbc/pybaseball/tree/master/docs <br>
# Statcast header meanings: https://baseballsavant.mlb.com/csv-docs

# %% [markdown]
# plate_x
# Horizontal position of the ball when it crosses home plate from the catcher's perspective.
#
# plate_z
# Vertical position of the ball when it crosses home plate from the catcher's perspective.

# %%
import pybaseball
import pandas as pd
import numpy as np
import random
from collections import Counter

# %%
def atbat(firstname, lastname, outs):
    batter_data = pybaseball.playerid_lookup('Judge', 'Aaron')
    batter_id = batter_data['key_mlbam'][0]

    # figure out all events that happen
    batter_data = pybaseball.statcast_batter('2018-01-01', '2022-01-01', batter_id)
    atbat_events = batter_data['events'].dropna()
    count_events = Counter(atbat_events)
    list_events = list(count_events)
    prob = []
    for x in count_events:
        prob.append(count_events[x])
    total_events = sum(prob)
    total = 0
    for x in range(len(prob)):
        prob[x] = (prob[x]/total_events) + total
        total = prob[x]

# %%
# What happens this atbat
atbat = random.random()
for x in prob:
    if x > atbat:
        event_index = prob.index(x)
        break
if 'out' in list_events[event_index]:
    outs+=1
else:
    print(list_events[event_index])

# %%
# home_lineup = [
# 'DJ LeMahieu',
# 'Aaron Judge',
# 'Anthony Rizzo',
# 'Giancarlo Stanton',
# 'Josh Donaldson',
# 'Matt Carpenter',
# 'Isiah Kiner-Falefa',
# 'Jose Trevino',
# 'Joey Gallo'
# ]
# outs = 0
# x = 0
# while outs < 3:
#     batter = home_lineup[x].split()
#     if outs < 3:
#         atbat(batter[0],batter[1],outs)
#     else:
#         break
#     x+=1
#     if x == 9:
#         x=0
# Out:
# Gathering player lookup table. This may take a moment.
# Gathering Player Data
# home_run
# Gathering Player Data
# Gathering Player Data
# grounded_into_double_play
# Gathering Player Data
# walk
# Gathering Player Data
# Gathering Player Data
# single
# Gathering Player Data
# Gathering Player Data
# home_run
# Gathering Player Data
# grounded_into_double_play
# Gathering Player Data
# walk
# Gathering Player Data
# walk
# Gathering Player Data
# double
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# home_run
# Gathering Player Data
# walk
# Gathering Player Data
# Gathering Player Data
# double
# Gathering Player Data
# single
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# single
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# walk
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# grounded_into_double_play
# Gathering Player Data
# home_run
# Gathering Player Data
# double
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# single
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# Gathering Player Data
# walk
# Gathering Player Data
# Gathering Player Data
# single
# Gathering Player Data
# walk
# Gathering Player Data
# home_run
# Gathering Player Data
# hit_by_pitch
# Gathering Player Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27540/2022085934.py in <module>
#      15     batter = home_lineup[x].split()
#      16     if outs < 3:
# ---> 17         atbat(batter[0],batter[1],outs)
#      18     else:
#      19         break
#
# ~\AppData\Local\Temp/ipykernel_27540/2309848976.py in atbat(firstname, lastname, outs)
#       4
#       5     # figure out all events that happen
# ----> 6     batter_data = pybaseball.statcast_batter('2018-01-01', '2022-01-01', batter_id)
#       7     atbat_events = batter_data['events'].dropna()
#       8     count_events = Counter(atbat_events)
#
# ~\anaconda3\lib\site-packages\pybaseball\statcast_batter.py in statcast_batter(start_dt, end_dt, player_id)
#      26
#      27     url = 'https://baseballsavant.mlb.com/statcast_search/csv?all=true&hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&stadium=&hfBBL=&hfNewZones=&hfGT=R%7CPO%7CS%7C=&hfSea=&hfSit=&player_type=batter&hfOuts=&opponent=&pitcher_throws=&batter_stands=&hfSA=&game_date_gt={}&game_date_lt={}&batters_lookup%5B%5D={}&team=&position=&hfRO=&home_road=&hfFlag=&metric_1=&hfInn=&min_pitches=0&min_results=0&group_by=name&sort_col=pitches&player_event_sort=h_launch_speed&sort_order=desc&min_abs=0&type=details&'
# ---> 28     df = split_request(start_dt, end_dt, player_id, url)
#      29     return df
#      30
#
# ~\anaconda3\lib\site-packages\pybaseball\cache\cache.py in _cached(*args, **kwargs)
#      56
#      57             if result is None:
# ---> 58                 result = func(*args, **kwargs)
#      59                 self._safe_save_func_cache(func_data, result)
#      60
#
# ~\anaconda3\lib\site-packages\pybaseball\utils.py in split_request(start_dt, end_dt, player_id, url)
#     222                 # retrieve data
#     223                 data = requests.get(url.format(start_str, end_str, player_id_str))
# --> 224                 df = pd.read_csv(io.StringIO(data.text))
#     225                 # add data to list and increment current dates
#     226                 results.append(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\common.py in is_extension_array_dtype(arr_or_dtype)
#    1418
#    1419
# -> 1420 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1421     """
#    1422     Check if an object is a pandas extension array type.
#
# KeyboardInterrupt:
